# %% [markdown]
# <a href="https://colab.research.google.com/github/MarieIS/Python_HW9/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
adv1_df = pd.read_csv('sample_data/advertising_1.csv')

# %%
adv1_df['Number'].head(n = 10)
# Out:
# 0     5
# 1     6
# 2     8
# 3     9
# 4    10
# 5    11
# 6    12
# 7    13
# 8    14
# 9    15
# Name: Number, dtype: int64

# %%
adv1_df.shape
# Out:
# (500, 5)

# %%
adv1_df[adv1_df['Number'] == 8]['Daily Internet Usage']
# Out:
# 2    245.89
# Name: Daily Internet Usage, dtype: float64

# %%
adv2_df = pd.read_csv('sample_data/advertising_2.csv')

# %%
adv2_df.loc[(533 <= adv2_df['Number']) & (adv2_df['Number'] <= 536)]
# Out:
#    Number  Daily Time Spent on Site  Daily Internet Usage  \
# 3     533                     46.61                   NaN
# 4     534                       NaN                162.03
# 5     535                     65.10                118.10
# 6     536                     53.44                   NaN
#
#                            Ad Topic Line  Clicked on Ad
# 3          Ergonomic methodical encoding              1
# 4      Compatible dedicated productivity              0
# 5         Up-sized real-time methodology              1
# 6  Up-sized next generation architecture              1
